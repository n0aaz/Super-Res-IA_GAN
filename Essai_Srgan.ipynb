# %%
from SRGAN import SRGAN as srgan

SR=srgan()

SR.train(40)
# Out:
# lr_shape,hrshape= (56, 56, 3) (224, 224, 3)
# REGARDE ICI :  (None, 224, 224, 3) (224, 224, 3)
# batch size=  16 16
# 16 16
# train_generator line 90 , shape of lowres : (16, 224, 224, 3)
# Generation n°:0
# Duree: 0:00:14.257902
# Duree Totale:0:00:14.257901
# batch size=  16 16
# 16 16
# train_generator line 90 , shape of lowres : (16, 224, 224, 3)
# Generation n°:1
# Duree: 0:00:02.003221
# Duree Totale:0:00:16.261202
# batch size=  16 16
# 16 16
# train_generator line 90 , shape of lowres : (16, 224, 224, 3)
# Generation n°:2
# Duree: 0:00:01.386136
# Duree Totale:0:00:17.647428
# batch size=  16 16
# 16 16
# train_generator line 90 , shape of lowres : (16, 224, 224, 3)
# Generation n°:3
# Duree: 0:00:03.195603
# Duree Totale:0:00:20.843107
# batch size=  16 16
# 16 16
# train_generator line 90 , shape of lowres : (16, 224, 224, 3)
# Generation n°:4
# Duree: 0:00:01.422761
# Duree Totale:0:00:22.265941
# batch size=  16 16
# 16 16
# ...

# %%
SR.sauvegarde_modele()
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/resource_variable_ops.py:1813: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: Model/Generateur/assets
# INFO:tensorflow:Assets written to: Model/Discriminateur/assets
# INFO:tensorflow:Assets written to: Model/modeleCombine/assets

# %%
# Essayons d'avoir un aperçu
from SRGAN import SRGAN as srgan

SR=srgan()
# Out:
# REGARDE ICI :  (None, 224, 224, 3) (224, 224, 3)

# %%
SR.charger_modeles()
# Out:
# Chargement du modèle depuis  Model/  en cours ...
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Compilation du discriminateur...
# Compilation du modèle combiné...
# Modèle chargé !

# %%
SR.echantillon_images(15)

# %%
from ImageSuperRes import ImageSuperRes as ISR

# %%
superRes = ISR(56,56)

# %%
image = superRes.decoupe_images('./cc.jpg')
print(image.shape)
# Out:
# (23, 27, 56, 56, 3)

# %%
import matplotlib.pyplot as plt

# %%
for morceau in image:
    plt.figure()
    plt.imshow(morceau.astype("float")/255.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-38823be84101> in <module>
#       1 for morceau in image:
#       2     plt.figure()
# ----> 3     plt.imshow(morceau.astype("float")/255.0)
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2722         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2723         data=None, **kwargs):
# -> 2724     __ret = gca().imshow(
#    2725         X, cmap=cmap, norm=norm, aspect=aspect,
#    2726         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# ...

# %%
image2 = superRes.reconstitue_image(superRes.decoupe_images('cc.jpg'))/255.0
# Out:
# 56 56
# [[[191 127 92]
#   [191 127 92]
#   [190 127 92]
#   [190 127 92]
#   [190 127 92]
#   [190 127 92]
#   [190 127 92]
#   [188 128 92]
#   [186 126 90]
#   [186 126 90]]
#
#  [[191 127 92]
#   [191 127 92]
#   [191 127 92]
#   [190 127 92]
#   [190 127 92]
#   [190 127 92]
#   [190 127 92]
#   [188 128 92]
#   [186 126 90]
#   [186 126 90]]
#
#  [[191 127 92]
#   [191 127 92]
#   [191 127 92]
#   [191 127 92]
#   [190 127 92]
#   [190 127 92]
#   [190 127 92]
#   [190 127 92]
#   [186 126 90]
#   [186 126 90]]
#
#  [[191 127 92]
#   [191 127 92]
#   [191 127 92]
#   [191 127 92]
#   [191 127 92]
#   [190 127 92]
#   [190 127 92]
#   [190 127 92]
#   [189 126 91]
#   [187 127 91]]
#
#  [[192 126 92]
#   [192 126 92]
#   [191 127 92]
#   [191 127 92]
#   [191 127 92]
#   [191 127 92]
#   [191 127 92]
#   [190 127 92]
#   [189 126 91]
#   [189 126 91]]
#
#  [[192 126 92]
#   [192 126 92]
#   [192 126 92]
#   [192 126 92]
#   [192 126 92]
#   [191 127 92]
#   [191 127 92]
# ...

# %%
plt.imshow(superRes.reconstitue_image(image/255.0))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
from ImageSuperRes import ImageSuperRes as ISR
import matplotlib.pyplot as plt
superRes = ISR(56,56)
from PIL import Image

image_sortie=superRes.superResolution('./tiger.bmp')
# Out:
# REGARDE ICI :  (None, 224, 224, 3) (224, 224, 3)
# Chargement du modèle depuis  Model/  en cours ...
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Compilation du discriminateur...
# Compilation du modèle combiné...
# Modèle chargé !
#
# 224 224
# [[[254.99880981445312 0.0 0.0]
#   [255.0 0.0 0.0]
#   [255.0 0.0 0.0]
#   [255.0 0.0 0.0]
#   [255.0 0.0 0.0]
#   [255.0 0.0 0.0]
#   [255.0 0.0 0.0]
#   [255.0 0.0 0.0]
#   [255.0 0.0 0.0]
#   [255.0 0.0 0.0]]
#
#  [[254.9553680419922 0.0 0.0]
#   [255.0 0.0 0.0]
#   [255.0 0.0 0.0]
#   [255.0 0.0 0.0]
#   [255.0 0.0 0.0]
#   [255.0 0.0 0.0]
#   [255.0 0.0 0.0]
#   [255.0 0.0 0.0]
#   [255.0 0.0 0.0]
#   [255.0 0.0 0.0]]
#
#  [[229.85411071777344 0.0 0.0]
#   [254.99998474121094 0.0 0.0]
#   [255.0 0.0 0.0]
#   [255.0 0.0 0.0]
#   [255.0 0.0 0.0]
#   [255.0 0.0 0.0]
#   [255.0 0.0 0.0]
#   [255.0 0.0 0.0]
#   [255.0 0.0 0.0]
#   [255.0 0.0 0.0]]
#
# ...

# %%
plt.figure(figsize=(20,10))
plt.subplot(121)
plt.imshow(image_sortie/255.0)
plt.subplot(122)
plt.imshow(Image.open('./tiger.bmp'))

# %%
from DataLoader import DataLoader
loader= DataLoader("MS_Coco",resolution=(224,224))
loader.batch_size=3
highres,lowres= loader.load_data()

# %%
plt.figure(figsize=(20,10))
plt.subplot(121)
plt.imshow(0.5*highres[0]+0.5)
plt.subplot(122)
plt.imshow(0.5*lowres[0]+0.5)

# %%
from SRGAN import SRGAN
sr= SRGAN()
sr.charger_modeles()
sr.echantillon_images(3)
# Out:
# REGARDE ICI :  (None, 224, 224, 3) (224, 224, 3)
# Chargement du modèle depuis  Model/  en cours ...
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Compilation du discriminateur...
# Compilation du modèle combiné...
# Modèle chargé !

# %%
#print(0.5*highres[0]+0.5)
sortie=sr.generateur.predict(lowres)
plt.figure(figsize=(20,10))
plt.subplot(121)
plt.imshow(0.5*sortie[2]+0.5)
plt.subplot(122)
plt.imshow(0.5*lowres[2]+0.5)

# %%
### Il semblerait que notre modèle ne soit clairement pas assez entrainé.
