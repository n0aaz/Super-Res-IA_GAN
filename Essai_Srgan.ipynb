# %%
from SRGAN import SRGAN as srgan

SR=srgan()

SR.train(100)
# Out:
# REGARDE ICI :  (None, 224, 224, 3) (224, 224, 3)
# Generation n°:0
# Duree: 0:00:06.579018
# Duree Totale:0:00:06.579016
# Generation n°:1
# Duree: 0:00:00.115553
# Duree Totale:0:00:06.694660
# Generation n°:2
# Duree: 0:00:00.115426
# Duree Totale:0:00:06.810162
# Generation n°:3
# Duree: 0:00:00.114178
# Duree Totale:0:00:06.924410
# Generation n°:4
# Duree: 0:00:00.113986
# Duree Totale:0:00:07.038467
# Generation n°:5
# Duree: 0:00:00.113526
# Duree Totale:0:00:07.152058
# Generation n°:6
# Duree: 0:00:00.117057
# Duree Totale:0:00:07.269182
# Generation n°:7
# Duree: 0:00:00.113961
# Duree Totale:0:00:07.383200
# Generation n°:8
# Duree: 0:00:00.114035
# Duree Totale:0:00:07.497306
# Generation n°:9
# Duree: 0:00:00.113682
# Duree Totale:0:00:07.611189
# Generation n°:10
# Duree: 0:00:00.113743
# Duree Totale:0:00:07.725009
# Generation n°:11
# Duree: 0:00:00.117114
# Duree Totale:0:00:07.842182
# Generation n°:12
# Duree: 0:00:00.114727
# Duree Totale:0:00:07.957141
# ...

# %%
# Out:
#   File "<ipython-input-1-0e851521de5d>", line 1
#     wget https://raw.githubusercontent.com/openimages/dataset/master/downloader.py
#          ^
# SyntaxError: invalid syntax
