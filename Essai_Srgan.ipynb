# %%
from SRGAN import SRGAN as srgan

SR=srgan()

SR.train(100)
# Out:
# REGARDE ICI :  (None, 224, 224, 3) (224, 224, 3)
# Generation n°:0
# Duree: 0:00:06.756692
# Duree Totale:0:00:06.756688
# Generation n°:1
# Duree: 0:00:00.115702
# Duree Totale:0:00:06.872489
# Generation n°:2
# Duree: 0:00:00.116684
# Duree Totale:0:00:06.989237
# Generation n°:3
# Duree: 0:00:00.115608
# Duree Totale:0:00:07.104899
# Generation n°:4
# Duree: 0:00:00.115408
# Duree Totale:0:00:07.220378
# Generation n°:5
# Duree: 0:00:00.113965
# Duree Totale:0:00:07.334398
# Generation n°:6
# Duree: 0:00:00.117680
# Duree Totale:0:00:07.452145
# Generation n°:7
# Duree: 0:00:00.115051
# Duree Totale:0:00:07.567259
# Generation n°:8
# Duree: 0:00:00.115100
# Duree Totale:0:00:07.682459
# Generation n°:9
# Duree: 0:00:00.114608
# Duree Totale:0:00:07.797123
# Generation n°:10
# Duree: 0:00:00.113321
# Duree Totale:0:00:07.910517
# Generation n°:11
# Duree: 0:00:00.117816
# Duree Totale:0:00:08.028391
# Generation n°:12
# Duree: 0:00:00.114382
# Duree Totale:0:00:08.142835
# ...

# %%
SR.sauvegarde_modele()
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/resource_variable_ops.py:1813: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: Model/Generateur/assets
# INFO:tensorflow:Assets written to: Model/Discriminateur/assets
# INFO:tensorflow:Assets written to: Model/modeleCombine/assets
